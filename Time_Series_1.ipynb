# %%
#import libraries
import tensorflow as tf
import os
import pandas as pd
import numpy as np

# %%
# Downloading data from tensorflow for analysis
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)
csv_path, _ = os.path.splitext(zip_path)
# Out:
# ...
# 13568290/13568290 [==============================] - 0s 0us/step

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
# Get data point for every hour
df = df[5::6]
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 35      01.01.2009 06:00:00    997.71     -9.67    263.66       -10.62
# 71      01.01.2009 12:00:00   1000.30     -6.87    266.27        -8.28
# 107     01.01.2009 18:00:00   1000.16     -5.25    267.90        -6.75
# 143     02.01.2009 00:00:00    999.59     -4.54    268.65        -5.46
# 179     02.01.2009 06:00:00    998.00     -4.43    268.88        -4.94
# ...                     ...       ...       ...       ...          ...
# 420371  30.12.2016 18:10:00   1008.92      0.38    272.84        -1.87
# 420407  31.12.2016 00:10:00   1008.64     -4.17    268.33        -5.36
# 420443  31.12.2016 06:10:00   1006.59     -5.17    267.48        -9.31
# 420479  31.12.2016 12:10:00   1004.62     -0.71    272.09        -5.97
# 420515  31.12.2016 18:10:00   1002.27     -0.42    272.56        -4.92
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df.tail()
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 420521   72.00          5.69          4.09          1.59       2.54
# 420527   66.29          5.51          3.65          1.86       2.27
# 420533   72.90          4.99          3.64          1.35       2.26
# 420539   72.30          4.93          3.57          1.37       2.22
# 420545   72.60          4.56          3.31          1.25       2.06
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# ...

# %%
#Set Time to index
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')
df[:26]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71     -9.67    263.66
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30     -6.87    266.27
# 2009-01-01 18:00:00  01.01.2009 18:00:00   1000.16     -5.25    267.90
# 2009-01-02 00:00:00  02.01.2009 00:00:00    999.59     -4.54    268.65
# 2009-01-02 06:00:00  02.01.2009 06:00:00    998.00     -4.43    268.88
# 2009-01-02 12:00:00  02.01.2009 12:00:00    998.91     -3.12    270.13
# 2009-01-02 18:00:00  02.01.2009 18:00:00   1000.74     -3.07    270.03
# 2009-01-03 00:00:00  03.01.2009 00:00:00   1002.32     -4.71    268.27
# 2009-01-03 06:00:00  03.01.2009 06:00:00   1001.29     -8.20    264.86
# 2009-01-03 12:00:00  03.01.2009 12:00:00    999.02     -5.96    267.28
# 2009-01-03 18:00:00  03.01.2009 18:00:00    995.48     -4.08    269.43
# 2009-01-04 00:00:00  04.01.2009 00:00:00    992.93     -1.90    271.81
# ...

# %%
temp = df['T (degC)']
temp.plot()

# %%
#Preparing our data for our model
# [[[1,2,3], [2,3,3], [3], [4], [5]]] [6]
# [[[2], [3], [4], [5], [6]]] [7]
# [[[3], [4], [5], [6], [7]]] [8]

def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
X1.shape, y1.shape
# Out:
# ((11676, 5, 1), (11676,))

# %%
#Data Splitting
X_train1, y_train1 = X1[:60000], y1[:60000]
X_val1, y_val1 = X1[60000:65000], y1[60000:65000]
X_test1, y_test1 = X1[65000:], y1[65000:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (5086, 5, 1), (5086,))

# %%
#Import necessary libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
#Model Creation
model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# ...
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model Save using checkpoints
cp1 = ModelCheckpoint('model1/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp1])
# Out:
# Epoch 1/10
# 1872/1875 [============================>.] - ETA: 0s - loss: 67.6195 - root_mean_squared_error: 8.2231
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 1875/1875 [==============================] - 18s 6ms/step - loss: 67.5393 - root_mean_squared_error: 8.2182 - val_loss: 4.0821 - val_root_mean_squared_error: 2.0204
# Epoch 2/10
# 1870/1875 [============================>.] - ETA: 0s - loss: 7.4943 - root_mean_squared_error: 2.7376
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 1875/1875 [==============================] - 10s 6ms/step - loss: 7.4813 - root_mean_squared_error: 2.7352 - val_loss: 0.7689 - val_root_mean_squared_error: 0.8769
# ...

# %%
#Loading model from Checkpoint
from tensorflow.keras.models import load_model
model1 = load_model('model1/')

# %%
#Check performance between the predicted and real
train_predictions = model1.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 1875/1875 [==============================] - 4s 2ms/step
#        Train Predictions  Actuals
# 0             -10.100076    -9.67
# 1              -9.910817    -9.17
# 2              -9.043830    -8.10
# 3              -7.589929    -7.66
# 4              -7.398862    -7.04
# ...                  ...      ...
# 59995           6.056643     6.07
# 59996           7.105026     9.88
# 59997          12.061332    13.53
# 59998          15.694520    15.43
# 59999          16.316322    15.54
#
# [60000 rows x 2 columns]

# %%
#Visual Representation of Compara
import matplotlib.pyplot as plt
plt.plot(train_results['Train Predictions'][50:100], color = 'red')
plt.plot(train_results['Actuals'][50:100])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-51126c61f4b3> in <module>
#       1 #Visual Representation of Compara
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.plot(train_results['Train Predictions'][50:100], color = 'red')
#       4 plt.plot(train_results['Actuals'][50:100])
#
# NameError: name 'train_results' is not defined

# %%
val_predictions = model1.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 157/157 [==============================] - 1s 2ms/step
#       Val Predictions  Actuals
# 0           15.502653    14.02
# 1           13.179797    13.67
# 2           13.003398    12.27
# 3           11.498378    11.19
# 4           10.385711    10.85
# ...               ...      ...
# 4995        17.393719    18.27
# 4996        17.246098    17.85
# 4997        17.186716    16.65
# 4998        15.821414    15.85
# 4999        15.016389    15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][:100])
plt.plot(val_results['Actuals'][:100])

# %%
test_predictions = model1.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 159/159 [==============================] - 1s 4ms/step
#       Test Predictions  Actuals
# 0            14.378614    13.99
# 1            13.230301    13.46
# 2            12.871506    12.93
# 3            12.496793    12.43
# 4            12.044730    12.17
# ...                ...      ...
# 5081         -1.078245    -0.98
# 5082         -1.493810    -1.40
# 5083         -1.742770    -2.75
# 5084         -3.167897    -2.89
# 5085         -3.208487    -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])
